# %%
import findata

# %%
# AAPL의 최근 Form 4 내부자 거래 (기본 5건의 Filing)
trades = findata.get_insider_trades("AAPL")

# 더 많이 가져오려면 count 조절
trades = findata.get_insider_trades("AAPL", count=20)

# %%
trades
# Out:
# [{'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126023363/0001140361-26-023363.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-27',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-29T18:30:27-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': 'true',
#   'is_officer': '',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-05-27',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '50000',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '311.02',
#   'shares_owned_after': '3764576',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 1.31,
#   'transaction_value': 15551000.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126023363/0001140361-26-023363.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-27',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-29T18:30:27-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': 'true',
#   'is_officer': '',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-05-27',
#   'transaction_code': 'G',
#   'transaction_code_description': 'Bona fide gift',
#   'amount': '65000',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '0',
#   'shares_owned_after': '3699576',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 1.73,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126020871/0001140361-26-020871.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-08',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-12T18:31:29-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Borders Ben',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Principal Accounting Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-05-08',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '1274',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '290',
#   'shares_owned_after': '38713',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 3.19,
#   'transaction_value': 369460.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126020298/0001140361-26-020298.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-06',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-08T18:30:09-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': 'true',
#   'is_officer': '',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-05-06',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '149527',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '284.57',
#   'shares_owned_after': '3920049',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 3.67,
#   'transaction_value': 42550898.39,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126020298/0001140361-26-020298.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-06',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-08T18:30:09-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': 'true',
#   'is_officer': '',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-05-06',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '100473',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '285.04',
#   'shares_owned_after': '3819576',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 2.56,
#   'transaction_value': 28638823.92,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126020298/0001140361-26-020298.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-06',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-08T18:30:09-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': 'true',
#   'is_officer': '',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-05-06',
#   'transaction_code': 'G',
#   'transaction_code_description': 'Bona fide gift',
#   'amount': '5000',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '0',
#   'shares_owned_after': '3814576',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.13,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126017175/0001140361-26-017175.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-23',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-27T18:30:44-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Parekh Kevan',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President, CFO',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-23',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '1534',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '275',
#   'shares_owned_after': '13366',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 10.3,
#   'transaction_value': 421850.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015421/0001140361-26-015421.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:32:12-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Borders Ben',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Principal Accounting Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '1717',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '40879',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 4.38,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015421/0001140361-26-015421.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:32:12-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Borders Ben',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Principal Accounting Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'F',
#   'transaction_code_description': 'Payment of exercise price or tax liability by delivering or withholding securities incident to the receipt, exercise or vesting of a security issued in accordance with Rule 16b-3',
#   'amount': '892',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '266.43',
#   'shares_owned_after': '39987',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 2.18,
#   'transaction_value': 237655.56,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015421/0001140361-26-015421.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:32:12-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Borders Ben',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Principal Accounting Officer',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '540',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '540',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 50.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015421/0001140361-26-015421.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:32:12-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Borders Ben',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Principal Accounting Officer',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '475',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '1423',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 25.03,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015421/0001140361-26-015421.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:32:12-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Borders Ben',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Principal Accounting Officer',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '371',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '1852',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 16.69,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015421/0001140361-26-015421.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:32:12-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Borders Ben',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Principal Accounting Officer',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '331',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '2312',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 12.52,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015420/0001140361-26-015420.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:30:34-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Parekh Kevan',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President, CFO',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '10928',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '19693',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 124.68,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015420/0001140361-26-015420.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:30:34-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Parekh Kevan',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President, CFO',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'F',
#   'transaction_code_description': 'Payment of exercise price or tax liability by delivering or withholding securities incident to the receipt, exercise or vesting of a security issued in accordance with Rule 16b-3',
#   'amount': '4793',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '266.43',
#   'shares_owned_after': '14900',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 24.34,
#   'transaction_value': 1276998.99,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015420/0001140361-26-015420.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:30:34-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Parekh Kevan',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President, CFO',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '5817',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '5816',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 50.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126015420/0001140361-26-015420.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-17T18:30:34-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Parekh Kevan',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President, CFO',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '5111',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '15331',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 25.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013192/0001140361-26-013192.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:45-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': "O'BRIEN DEIRDRE",
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '20338',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '255.12',
#   'shares_owned_after': '146474',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 12.19,
#   'transaction_value': 5188630.56,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013192/0001140361-26-013192.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:45-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': "O'BRIEN DEIRDRE",
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '9664',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '255.82',
#   'shares_owned_after': '136810',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 6.6,
#   'transaction_value': 2472244.48,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '5087',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '251.25',
#   'shares_owned_after': '3340280',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.15,
#   'transaction_value': 1278108.75,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '9147',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '252.11',
#   'shares_owned_after': '3331133',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.27,
#   'transaction_value': 2306050.17,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '1878',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '253.13',
#   'shares_owned_after': '3329255',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.06,
#   'transaction_value': 475378.14,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '16083',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '254.37',
#   'shares_owned_after': '3313172',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.48,
#   'transaction_value': 4091032.71,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '28188',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '255.17',
#   'shares_owned_after': '3284984',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.85,
#   'transaction_value': 7192731.96,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-02',
#   'transaction_code': 'S',
#   'transaction_code_description': 'Open market or private sale of non-derivative or derivative security',
#   'amount': '4566',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '256',
#   'shares_owned_after': '3280418',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.14,
#   'transaction_value': 1168896.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013192/0001140361-26-013192.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:45-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': "O'BRIEN DEIRDRE",
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '64317',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '201127',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 47.01,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013192/0001140361-26-013192.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:45-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': "O'BRIEN DEIRDRE",
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'F',
#   'transaction_code_description': 'Payment of exercise price or tax liability by delivering or withholding securities incident to the receipt, exercise or vesting of a security issued in accordance with Rule 16b-3',
#   'amount': '34315',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '255.63',
#   'shares_owned_after': '166812',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 17.06,
#   'transaction_value': 8771943.45,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013192/0001140361-26-013192.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:45-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': "O'BRIEN DEIRDRE",
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '22688',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '0',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013192/0001140361-26-013192.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:45-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': "O'BRIEN DEIRDRE",
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '22159',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '22159',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 50.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013192/0001140361-26-013192.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:45-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': "O'BRIEN DEIRDRE",
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Senior Vice President',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '19470',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '38938',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 33.33,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013191/0001140361-26-013191.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:43-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Khan Sabih',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'COO',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '64317',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '1107212',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 6.17,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013191/0001140361-26-013191.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:43-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Khan Sabih',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'COO',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'F',
#   'transaction_code_description': 'Payment of exercise price or tax liability by delivering or withholding securities incident to the receipt, exercise or vesting of a security issued in accordance with Rule 16b-3',
#   'amount': '33317',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '255.63',
#   'shares_owned_after': '1073895',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 3.01,
#   'transaction_value': 8516824.71,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013191/0001140361-26-013191.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:43-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Khan Sabih',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'COO',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '22688',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '0',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013191/0001140361-26-013191.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:43-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Khan Sabih',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'COO',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '22159',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '22159',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 50.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013191/0001140361-26-013191.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:43-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Khan Sabih',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'COO',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '19470',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '38938',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 33.33,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '131576',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '3411994',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 4.01,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'F',
#   'transaction_code_description': 'Payment of exercise price or tax liability by delivering or withholding securities incident to the receipt, exercise or vesting of a security issued in accordance with Rule 16b-3',
#   'amount': '66627',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '255.63',
#   'shares_owned_after': '3345367',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 1.95,
#   'transaction_value': 17031860.01,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '85080',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '0',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '22159',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '22159',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 50.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013190/0001140361-26-013190.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:41-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'COOK TIMOTHY D',
#   'is_director': 'true',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'Chief Executive Officer',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-04-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '24337',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '48673',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 33.33,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000178052526000005/0001780525-26-000005.txt',
#   'document_type': '4',
#   'period_of_report': '2026-03-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-03-17T18:31:17-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Newstead Jennifer',
#   'is_director': '0',
#   'is_officer': '1',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': 'SVP, GC and Secretary',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-03-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '60208',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '60208',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000178052526000005/0001780525-26-000005.txt',
#   'document_type': '4',
#   'period_of_report': '2026-03-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-03-17T18:31:17-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Newstead Jennifer',
#   'is_director': '0',
#   'is_officer': '1',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': 'SVP, GC and Secretary',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-03-15',
#   'transaction_code': 'F',
#   'transaction_code_description': 'Payment of exercise price or tax liability by delivering or withholding securities incident to the receipt, exercise or vesting of a security issued in accordance with Rule 16b-3',
#   'amount': '32528',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '250.12',
#   'shares_owned_after': '27680',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 54.03,
#   'transaction_value': 8135903.36,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000178052526000005/0001780525-26-000005.txt',
#   'document_type': '4',
#   'period_of_report': '2026-03-15',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-03-17T18:31:17-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Newstead Jennifer',
#   'is_director': '0',
#   'is_officer': '1',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': 'SVP, GC and Secretary',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-03-15',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '60208',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '240832',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 20.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000121412826000004/0001214128-26-000004.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:32:41-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-02-26',
#   'transaction_code': 'G',
#   'transaction_code_description': 'Bona fide gift',
#   'amount': '1113',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '0',
#   'shares_owned_after': '4069576',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 0.03,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000105923526000004/0001059235-26-000004.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:34:19-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'WAGNER SUSAN',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-24',
#   'transaction_code': 'A',
#   'transaction_code_description': 'Grant, award or other acquisition pursuant to Rule 16b-3(d)',
#   'amount': '1139',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '0',
#   'shares_owned_after': '1139',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
# ...
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:33:14-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LOZANO MONICA C',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-24',
#   'transaction_code': 'A',
#   'transaction_code_description': 'Grant, award or other acquisition pursuant to Rule 16b-3(d)',
#   'amount': '1139',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '0',
#   'shares_owned_after': '1139',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000121412826000004/0001214128-26-000004.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:32:41-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-24',
#   'transaction_code': 'A',
#   'transaction_code_description': 'Grant, award or other acquisition pursuant to Rule 16b-3(d)',
#   'amount': '1011',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '0',
#   'shares_owned_after': '1011',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000105140126000004/0001051401-26-000004.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:32:04-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'JUNG ANDREA',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-24',
#   'transaction_code': 'A',
#   'transaction_code_description': 'Grant, award or other acquisition pursuant to Rule 16b-3(d)',
#   'amount': '1139',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '0',
#   'shares_owned_after': '1139',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000145314926000005/0001453149-26-000005.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:31:24-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Gorsky Alex',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-24',
#   'transaction_code': 'A',
#   'transaction_code_description': 'Grant, award or other acquisition pursuant to Rule 16b-3(d)',
#   'amount': '1139',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '0',
#   'shares_owned_after': '1139',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000169088226000004/0001690882-26-000004.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:30:33-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Austin Wanda M',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-24',
#   'transaction_code': 'A',
#   'transaction_code_description': 'Grant, award or other acquisition pursuant to Rule 16b-3(d)',
#   'amount': '1139',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '0',
#   'shares_owned_after': '1139',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000105923526000002/0001059235-26-000002.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-03T18:37:10-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'WAGNER SUSAN',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-02-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '1255',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '63746',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 2.01,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000105923526000002/0001059235-26-000002.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-03T18:37:10-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'WAGNER SUSAN',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '1255',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '0',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000121651926000002/0001216519-26-000002.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-03T18:36:32-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'SUGAR RONALD D',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-02-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '1255',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '110566',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 1.15,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000121651926000002/0001216519-26-000002.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-03T18:36:32-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'SUGAR RONALD D',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '1255',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '0',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000117986426000002/0001179864-26-000002.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-03T18:35:54-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LOZANO MONICA C',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'nonDerivativeTransaction',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '2026-02-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '1255',
#   'acquired_or_disposed': 'A',
#   'price_per_share': '',
#   'shares_owned_after': '9862',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 14.58,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000117986426000002/0001179864-26-000002.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-03T18:35:54-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LOZANO MONICA C',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'derivativeTransaction',
#   'security_category': 'derivative',
#   'security_title': 'Restricted Stock Unit',
#   'transaction_date': '2026-02-01',
#   'transaction_code': 'M',
#   'transaction_code_description': 'Exercise or conversion of derivative security exempted pursuant to Rule 16b-3',
#   'amount': '1255',
#   'acquired_or_disposed': 'D',
#   'price_per_share': '',
#   'shares_owned_after': '0',
#   'ownership_form': 'D',
#   'nature_of_ownership': '',
#   'trade_ratio_pct': 100.0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126023363/0001140361-26-023363.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-27',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-29T18:30:27-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': 'true',
#   'is_officer': '',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': '',
#   'row_type': 'nonDerivativeHolding',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '',
#   'transaction_code': '',
#   'transaction_code_description': '',
#   'amount': '',
#   'acquired_or_disposed': '',
#   'price_per_share': '',
#   'shares_owned_after': '56000',
#   'ownership_form': 'I',
#   'nature_of_ownership': 'By Spouse',
#   'trade_ratio_pct': 0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126020298/0001140361-26-020298.txt',
#   'document_type': '4',
#   'period_of_report': '2026-05-06',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-05-08T18:30:09-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': 'true',
#   'is_officer': '',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': '',
#   'row_type': 'nonDerivativeHolding',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '',
#   'transaction_code': '',
#   'transaction_code_description': '',
#   'amount': '',
#   'acquired_or_disposed': '',
#   'price_per_share': '',
#   'shares_owned_after': '56000',
#   'ownership_form': 'I',
#   'nature_of_ownership': 'By Spouse',
#   'trade_ratio_pct': 0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000114036126013191/0001140361-26-013191.txt',
#   'document_type': '4',
#   'period_of_report': '2026-04-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-04-03T18:30:43-04:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'Khan Sabih',
#   'is_director': '',
#   'is_officer': 'true',
#   'is_ten_pct_owner': '',
#   'is_other': '',
#   'officer_title': 'COO',
#   'row_type': 'nonDerivativeHolding',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '',
#   'transaction_code': '',
#   'transaction_code_description': '',
#   'amount': '',
#   'acquired_or_disposed': '',
#   'price_per_share': '',
#   'shares_owned_after': '31632',
#   'ownership_form': 'I',
#   'nature_of_ownership': 'By family trust',
#   'trade_ratio_pct': 0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000121412826000004/0001214128-26-000004.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-24',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-26T18:32:41-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'LEVINSON ARTHUR D',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'nonDerivativeHolding',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '',
#   'transaction_code': '',
#   'transaction_code_description': '',
#   'amount': '',
#   'acquired_or_disposed': '',
#   'price_per_share': '',
#   'shares_owned_after': '56000',
#   'ownership_form': 'I',
#   'nature_of_ownership': 'By Spouse',
#   'trade_ratio_pct': 0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0},
#  {'source_url': 'https://www.sec.gov/Archives/edgar/data/320193/000105923526000002/0001059235-26-000002.txt',
#   'document_type': '4',
#   'period_of_report': '2026-02-01',
#   'ticker': 'AAPL',
#   'rss_updated': '2026-02-03T18:37:10-05:00',
#   'issuer_name': 'Apple Inc.',
#   'issuer_cik': '0000320193',
#   'issuer_symbol': 'AAPL',
#   'owner_name': 'WAGNER SUSAN',
#   'is_director': '1',
#   'is_officer': '0',
#   'is_ten_pct_owner': '0',
#   'is_other': '0',
#   'officer_title': '',
#   'row_type': 'nonDerivativeHolding',
#   'security_category': 'non-derivative',
#   'security_title': 'Common Stock',
#   'transaction_date': '',
#   'transaction_code': '',
#   'transaction_code_description': '',
#   'amount': '',
#   'acquired_or_disposed': '',
#   'price_per_share': '',
#   'shares_owned_after': '6042',
#   'ownership_form': 'I',
#   'nature_of_ownership': 'By spouse',
#   'trade_ratio_pct': 0,
#   'transaction_value': 0.0,
#   'market_value_after': 0.0,
#   'market_cap': 0}]
